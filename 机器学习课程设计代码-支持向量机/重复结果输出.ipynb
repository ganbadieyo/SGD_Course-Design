# %%
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/data')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/data'

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv',index_col='id')
train.head()
# Out:
#    keyword location                                               text  target
# id
# 1      NaN      NaN  Our Deeds are the Reason of this #earthquake M...       1
# 4      NaN      NaN             Forest fire near La Ronge Sask. Canada       1
# 5      NaN      NaN  All residents asked to 'shelter in place' are ...       1
# 6      NaN      NaN  13,000 people receive #wildfires evacuation or...       1
# 7      NaN      NaN  Just got sent this photo from Ruby #Alaska as ...       1

# %%
train.shape
# Out:
# (7613, 4)

# %%
np.sum(train.duplicated()) # 52份相同的
# Out:
# 52

# %%
train[train.duplicated()]
# Out:
#                   keyword  ... target
# id                         ...
# 68                 ablaze  ...      0
# 165            aftershock  ...      0
# 172            aftershock  ...      0
# 238   airplane%20accident  ...      1
# 907          bioterrorism  ...      1
# 916          bioterrorism  ...      0
# 3387           demolition  ...      0
# 3520           derailment  ...      1
# 3522           derailment  ...      1
# 3524           derailment  ...      1
# 3552           derailment  ...      1
# 3814             detonate  ...      0
# 3828             detonate  ...      0
# 3836             detonate  ...      0
# 3841             detonate  ...      0
# 4064            displaced  ...      1
# 4072            displaced  ...      1
# 4077            displaced  ...      1
# 4086            displaced  ...      1
# 4672             engulfed  ...      0
# 4684             engulfed  ...      0
# 4691             engulfed  ...      0
# 4952             exploded  ...      0
# ...
